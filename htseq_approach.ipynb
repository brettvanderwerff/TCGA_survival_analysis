# %%
from collections import Counter
import pandas as pd
import rpy2.rinterface
import numpy as np
# %load_ext rpy2.ipython

# %% [markdown]
# ## TGCA Survival Analysis of Pancreatic Cancer Patients
#
# ### Modified from similar workflow described on biostars.org: https://www.biostars.org/p/153013/

# %%
# Download raw counts from Xena, place tsv in data folder
# https://xenabrowser.net/datapages/?dataset=TCGA-PAAD%2FXena_Matrices%2FTCGA-PAAD.htseq_counts.tsv&host=https%3A%2F%2Fgdc.xenahubs.net&removeHub=https%3A%2F%2Fxena.treehouse.gi.ucsc.edu%3A443

# %%
HTSeq_raw_df = pd.read_csv("data/TCGA-PAAD.htseq_counts.tsv", sep="\t")

# %%
# Visualize the head of the file
HTSeq_raw_df.head()
# Out:
#            Ensembl_ID  TCGA-2J-AAB1-01A  TCGA-2J-AAB4-01A  TCGA-2J-AAB6-01A  \
# 0  ENSG00000000003.13         10.342075         10.997179         10.145932
# 1   ENSG00000000005.5          0.000000          0.000000          0.000000
# 2  ENSG00000000419.11          9.974415         10.329796         10.976564
# 3  ENSG00000000457.12          9.727920          9.751544          8.651052
# 4  ENSG00000000460.15          7.734710          7.942515          8.661778
#
#    TCGA-2J-AAB8-01A  TCGA-2J-AAB9-01A  TCGA-2J-AABA-01A  TCGA-2J-AABE-01A  \
# 0          9.424166          9.980140         10.856426         10.577429
# 1          2.584963          0.000000          0.000000          1.000000
# 2          9.531381          9.426265          9.930737          9.681238
# 3          9.398744          8.451211          9.231221         10.432542
# 4          7.672425          6.584963          7.383704          7.247928
#
#    TCGA-2J-AABF-01A  TCGA-2J-AABH-01A  ...  TCGA-XD-AAUH-01A  \
# 0         11.116994         10.512740  ...         10.290019
# 1          2.000000          1.584963  ...          3.807355
# 2         10.680360         10.299208  ...         10.104599
# 3         10.520619         10.328675  ...          9.497852
# 4          9.074141          8.055282  ...          7.159871
#
#    TCGA-XD-AAUI-01A  TCGA-XD-AAUL-01A  TCGA-XN-A8T3-01A  TCGA-XN-A8T5-01A  \
# 0         10.931476         11.259743         11.397140         10.302639
# 1          1.000000          1.000000          2.000000          1.584963
# 2         10.529431         10.484823         10.139551         10.225207
# 3          9.531381          9.463524          9.672425          9.002815
# 4          8.405141          7.900867          8.134426          7.159871
#
#    TCGA-YB-A89D-01A  TCGA-YB-A89D-11A  TCGA-YH-A8SY-01A  TCGA-YY-A8LH-01A  \
# 0         10.436712         10.644758         10.324181         10.901621
# 1          1.584963          8.383704          0.000000          0.000000
# 2         10.391244         10.267957         10.307201         10.611025
# 3          8.832890          8.731319          8.854868          9.868823
# 4          7.499846          7.294621          7.832890          8.044394
#
#    TCGA-Z5-AAPL-01A
# 0          9.390169
# 1          6.022368
# 2         10.604553
# 3          9.579316
# 4          8.134426
#
# [5 rows x 183 columns]

# %%
# These counts are actually partially processed (incremented by one then log transformed)
# We want to undo this so that we are working with the actual raw counts
HTSeq_raw_counts_df = pd.DataFrame()
HTSeq_raw_counts_df['Ensembl_ID'] = HTSeq_raw_df['Ensembl_ID']
for column in HTSeq_raw_df.columns.values[1:]:
    series = HTSeq_raw_df[column]
    series_antilog = (2**series) - 1
    HTSeq_raw_counts_df[column] = series_antilog

# %%
# Visualize the raw counts
HTSeq_raw_counts_df.head()
# Out:
#            Ensembl_ID  TCGA-2J-AAB1-01A  TCGA-2J-AAB4-01A  TCGA-2J-AAB6-01A  \
# 0  ENSG00000000003.13            1297.0            2043.0            1132.0
# 1   ENSG00000000005.5               0.0               0.0               0.0
# 2  ENSG00000000419.11            1005.0            1286.0            2014.0
# 3  ENSG00000000457.12             847.0             861.0             401.0
# 4  ENSG00000000460.15             212.0             245.0             404.0
#
#    TCGA-2J-AAB8-01A  TCGA-2J-AAB9-01A  TCGA-2J-AABA-01A  TCGA-2J-AABE-01A  \
# 0             686.0            1009.0            1853.0            1527.0
# 1               5.0               0.0               0.0               1.0
# 2             739.0             687.0             975.0             820.0
# 3             674.0             349.0             600.0            1381.0
# 4             203.0              95.0             166.0             151.0
#
#    TCGA-2J-AABF-01A  TCGA-2J-AABH-01A  ...  TCGA-XD-AAUH-01A  \
# 0            2220.0            1460.0  ...            1251.0
# 1               3.0               2.0  ...              13.0
# 2            1640.0            1259.0  ...            1100.0
# 3            1468.0            1285.0  ...             722.0
# 4             538.0             265.0  ...             142.0
#
#    TCGA-XD-AAUI-01A  TCGA-XD-AAUL-01A  TCGA-XN-A8T3-01A  TCGA-XN-A8T5-01A  \
# 0            1952.0            2451.0            2696.0            1262.0
# 1               1.0               1.0               3.0               2.0
# 2            1477.0            1432.0            1127.0            1196.0
# 3             739.0             705.0             815.0             512.0
# 4             338.0             238.0             280.0             142.0
#
#    TCGA-YB-A89D-01A  TCGA-YB-A89D-11A  TCGA-YH-A8SY-01A  TCGA-YY-A8LH-01A  \
# 0            1385.0            1600.0            1281.0            1912.0
# 1               2.0             333.0               0.0               0.0
# 2            1342.0            1232.0            1266.0            1563.0
# 3             455.0             424.0             462.0             934.0
# 4             180.0             156.0             227.0             263.0
#
#    TCGA-Z5-AAPL-01A
# 0             670.0
# 1              64.0
# 2            1556.0
# 3             764.0
# 4             280.0
#
# [5 rows x 183 columns]

# %%
# Need to figure out which columns are tumor samples and which columns are normal samples
origin_dict = {}
for column in list(HTSeq_raw_counts_df)[1:]:
    if column[13] == '0':
        origin_dict[column] = 'tumor'
    elif column[13] == '1':
        origin_dict[column] = 'normal'

# %%
# Count the number of occurances of each tumor or normal tissue
Counter(origin_dict.values())
# Out:
# Counter({'tumor': 178, 'normal': 4})

# %%
# For this analysis I am only interested in tumor samples
# I subset the HTSeq_raw_counts_df to just get tumor samples
slice_list = ['Ensembl_ID']
for column, value in origin_dict.items():
    if value == 'tumor':
        slice_list.append(column)
        
HTSeq_raw_counts_tumors_df = HTSeq_raw_counts_df[slice_list]

# %%
# Visualize the HTSeq_raw_counts_tumors_df
HTSeq_raw_counts_tumors_df.head()
# Out:
#            Ensembl_ID  TCGA-2J-AAB1-01A  TCGA-2J-AAB4-01A  TCGA-2J-AAB6-01A  \
# 0  ENSG00000000003.13            1297.0            2043.0            1132.0
# 1   ENSG00000000005.5               0.0               0.0               0.0
# 2  ENSG00000000419.11            1005.0            1286.0            2014.0
# 3  ENSG00000000457.12             847.0             861.0             401.0
# 4  ENSG00000000460.15             212.0             245.0             404.0
#
#    TCGA-2J-AAB8-01A  TCGA-2J-AAB9-01A  TCGA-2J-AABA-01A  TCGA-2J-AABE-01A  \
# 0             686.0            1009.0            1853.0            1527.0
# 1               5.0               0.0               0.0               1.0
# 2             739.0             687.0             975.0             820.0
# 3             674.0             349.0             600.0            1381.0
# 4             203.0              95.0             166.0             151.0
#
#    TCGA-2J-AABF-01A  TCGA-2J-AABH-01A  ...  TCGA-XD-AAUG-01A  \
# 0            2220.0            1460.0  ...            1126.0
# 1               3.0               2.0  ...              33.0
# 2            1640.0            1259.0  ...             835.0
# 3            1468.0            1285.0  ...             462.0
# 4             538.0             265.0  ...             106.0
#
#    TCGA-XD-AAUH-01A  TCGA-XD-AAUI-01A  TCGA-XD-AAUL-01A  TCGA-XN-A8T3-01A  \
# 0            1251.0            1952.0            2451.0            2696.0
# 1              13.0               1.0               1.0               3.0
# 2            1100.0            1477.0            1432.0            1127.0
# 3             722.0             739.0             705.0             815.0
# 4             142.0             338.0             238.0             280.0
#
#    TCGA-XN-A8T5-01A  TCGA-YB-A89D-01A  TCGA-YH-A8SY-01A  TCGA-YY-A8LH-01A  \
# 0            1262.0            1385.0            1281.0            1912.0
# 1               2.0               2.0               0.0               0.0
# 2            1196.0            1342.0            1266.0            1563.0
# 3             512.0             455.0             462.0             934.0
# 4             142.0             180.0             227.0             263.0
#
#    TCGA-Z5-AAPL-01A
# 0             670.0
# 1              64.0
# 2            1556.0
# 3             764.0
# 4             280.0
#
# [5 rows x 179 columns]

# %%
# Probably a good idea to remove lowly expressed genes
# Find out where genes have expression of 0 if 50% of samples
zeroes = (HTSeq_raw_counts_tumors_df == 0).astype(int)
zeroes_count = zeroes.sum(axis=1).to_frame()
length = zeroes.shape[1]
zeroes_count = zeroes_count.drop(zeroes_count[zeroes_count[0] < length/2].index)
drop_index_list = zeroes_count.index.to_list()

# %%
# Drop rows where genes have expression of 0 if 50% of samples
HTSeq_raw_counts_tumors_no_zeroes_df = HTSeq_raw_counts_tumors_df.drop(labels=drop_index_list)

# %%
# Determine how many rows were dropped due to low gene expression
before_drop = HTSeq_raw_counts_tumors_df.shape[0]
after_drop = HTSeq_raw_counts_tumors_no_zeroes_df.shape[0]
number_dropped = before_drop - after_drop
number_dropped
# Out:
# 29034

# %%
# Need to convert floats counts to integer, otherwise DESeq2 will complain
for column in HTSeq_raw_counts_tumors_no_zeroes_df.columns.values[1:]:
    HTSeq_raw_counts_tumors_no_zeroes_df[column] = HTSeq_raw_counts_tumors_no_zeroes_df[column].astype(int)

# %%
# Visualize results of float -> int conversion
HTSeq_raw_counts_tumors_no_zeroes_df.head()
# Out:
#            Ensembl_ID  TCGA-2J-AAB1-01A  TCGA-2J-AAB4-01A  TCGA-2J-AAB6-01A  \
# 0  ENSG00000000003.13              1297              2042              1131
# 1   ENSG00000000005.5                 0                 0                 0
# 2  ENSG00000000419.11              1005              1285              2013
# 3  ENSG00000000457.12               846               861               401
# 4  ENSG00000000460.15               212               245               403
#
#    TCGA-2J-AAB8-01A  TCGA-2J-AAB9-01A  TCGA-2J-AABA-01A  TCGA-2J-AABE-01A  \
# 0               686              1009              1852              1526
# 1                 4                 0                 0                 1
# 2               739               686               974               820
# 3               674               348               599              1381
# 4               202                94               165               150
#
#    TCGA-2J-AABF-01A  TCGA-2J-AABH-01A  ...  TCGA-XD-AAUG-01A  \
# 0              2219              1459  ...              1126
# 1                 3                 1  ...                32
# 2              1639              1259  ...               834
# 3              1468              1284  ...               461
# 4               537               264  ...               105
#
#    TCGA-XD-AAUH-01A  TCGA-XD-AAUI-01A  TCGA-XD-AAUL-01A  TCGA-XN-A8T3-01A  \
# 0              1250              1952              2451              2695
# 1                13                 1                 1                 3
# 2              1100              1476              1432              1127
# 3               721               739               704               814
# 4               142               338               237               279
#
#    TCGA-XN-A8T5-01A  TCGA-YB-A89D-01A  TCGA-YH-A8SY-01A  TCGA-YY-A8LH-01A  \
# 0              1262              1384              1280              1911
# 1                 1                 1                 0                 0
# 2              1195              1341              1265              1562
# 3               512               454               461               933
# 4               142               179               226               263
#
#    TCGA-Z5-AAPL-01A
# 0               669
# 1                64
# 2              1556
# 3               763
# 4               279
#
# [5 rows x 179 columns]

# %%
# Iteratively save a tsv corresponing to the raw counts for each tumor
# needed to pass data off to DESeq2
for column in HTSeq_raw_counts_tumors_no_zeroes_df.columns.values[1:]:
    file_name = 'data/tumor_samples/' + column + '.tsv'
    HTSeq_raw_counts_tumors_no_zeroes_df[['Ensembl_ID', column]].to_csv(file_name, sep=" ", header=False, index=False)

# %%
# %%R
# # load the R libraries
# library("DESeq2")
# Out:
# R[write to console]: Loading required package: S4Vectors
#
# R[write to console]: Loading required package: stats4
#
# R[write to console]: Loading required package: BiocGenerics
#
# R[write to console]: Loading required package: parallel
#
# R[write to console]:
# Attaching package: ‘BiocGenerics’
#
#
# R[write to console]: The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colMeans,
#     colnames, colSums, dirname, do.call, duplicated, eval, evalq,
#     Filter, Find, get, grep, grepl, intersect, is.unsorted, lapply,
#     lengths, Map, mapply, match, mget, order, paste, pmax, pmax.int,
#     pmin, pmin.int, Position, rank, rbind, Reduce, rowMeans, rownames,
#     rowSums, sapply, setdiff, sort, table, tapply, union, unique,
#     unsplit, which, which.max, which.min
#
#
# R[write to console]:
# Attaching package: ‘S4Vectors’
#
#
# R[write to console]: The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# R[write to console]: Loading required package: IRanges
#
# R[write to console]: Loading required package: GenomicRanges
#
# R[write to console]: Loading required package: GenomeInfoDb
#
# R[write to console]: Loading required package: SummarizedExperiment
#
# R[write to console]: Loading required package: Biobase
#
# R[write to console]: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# R[write to console]: Loading required package: DelayedArray
#
# R[write to console]: Loading required package: matrixStats
#
# R[write to console]:
# Attaching package: ‘matrixStats’
#
#
# R[write to console]: The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
#
# R[write to console]: Loading required package: BiocParallel
#
# R[write to console]:
# Attaching package: ‘DelayedArray’
#
#
# R[write to console]: The following objects are masked from ‘package:matrixStats’:
#
#     colMaxs, colMins, colRanges, rowMaxs, rowMins, rowRanges
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     aperm, apply

# %%
# %%R
# # Asssign the directory of the rna samples
# rna_data_directory <- 'data/tumor_samples'
#
# # Build the sampleTable based on the data files we have
# sampleFiles <- list.files(rna_data_directory)
# sampleNames <- gsub(".tsv", "", sampleFiles)
# sampleCondition <- c(rep("tumor", 178))
# sampleTable <- data.frame(sampleName = sampleNames,
#                           fileName = sampleFiles,
#                           condition = sampleCondition)
# Out:
#           sampleName             fileName condition
# 1   TCGA-2J-AAB1-01A TCGA-2J-AAB1-01A.tsv     tumor
# 2   TCGA-2J-AAB4-01A TCGA-2J-AAB4-01A.tsv     tumor
# 3   TCGA-2J-AAB6-01A TCGA-2J-AAB6-01A.tsv     tumor
# 4   TCGA-2J-AAB8-01A TCGA-2J-AAB8-01A.tsv     tumor
# 5   TCGA-2J-AAB9-01A TCGA-2J-AAB9-01A.tsv     tumor
# 6   TCGA-2J-AABA-01A TCGA-2J-AABA-01A.tsv     tumor
# 7   TCGA-2J-AABE-01A TCGA-2J-AABE-01A.tsv     tumor
# 8   TCGA-2J-AABF-01A TCGA-2J-AABF-01A.tsv     tumor
# 9   TCGA-2J-AABH-01A TCGA-2J-AABH-01A.tsv     tumor
# 10  TCGA-2J-AABI-01A TCGA-2J-AABI-01A.tsv     tumor
# 11  TCGA-2J-AABK-01A TCGA-2J-AABK-01A.tsv     tumor
# 12  TCGA-2J-AABO-01A TCGA-2J-AABO-01A.tsv     tumor
# 13  TCGA-2J-AABP-01A TCGA-2J-AABP-01A.tsv     tumor
# 14  TCGA-2J-AABR-01A TCGA-2J-AABR-01A.tsv     tumor
# 165 TCGA-US-A779-01A TCGA-US-A779-01A.tsv     tumor
# 166 TCGA-US-A77E-01A TCGA-US-A77E-01A.tsv     tumor
# 167 TCGA-US-A77G-01A TCGA-US-A77G-01A.tsv     tumor
# 168 TCGA-US-A77J-01A TCGA-US-A77J-01A.tsv     tumor
# 169 TCGA-XD-AAUG-01A TCGA-XD-AAUG-01A.tsv     tumor
# 170 TCGA-XD-AAUH-01A TCGA-XD-AAUH-01A.tsv     tumor
# 171 TCGA-XD-AAUI-01A TCGA-XD-AAUI-01A.tsv     tumor
# 172 TCGA-XD-AAUL-01A TCGA-XD-AAUL-01A.tsv     tumor
# 173 TCGA-XN-A8T3-01A TCGA-XN-A8T3-01A.tsv     tumor
# 174 TCGA-XN-A8T5-01A TCGA-XN-A8T5-01A.tsv     tumor
# 175 TCGA-YB-A89D-01A TCGA-YB-A89D-01A.tsv     tumor
# 176 TCGA-YH-A8SY-01A TCGA-YH-A8SY-01A.tsv     tumor
# 177 TCGA-YY-A8LH-01A TCGA-YY-A8LH-01A.tsv     tumor
# 178 TCGA-Z5-AAPL-01A TCGA-Z5-AAPL-01A.tsv     tumor

# %%
# %%R
#
# # Make a DESeq dataset using the sample table and directory to the datafiles
# # The design is set to 1 to indicate that there are no factors dividing these groups
# # i.e. they are all tumor samples, see: https://support.bioconductor.org/p/64122/
# dds <- DESeqDataSetFromHTSeqCount(sampleTable = sampleTable,
#                                        directory = rna_data_directory,
#                                        design= ~ 1)

# %%
# %%R
#
# # http://people.duke.edu/~ccc14/duke-hts-2017/Statistics/08032017/DESeq2-Notebook-introduction.html
# # Tranform raw counts to rlog
# # Transformation takes several hours, will load R object with results already if already exists
#
# if (!file.exists("transformed_dds.rds")) {
#
#         transformed_dds <- rlog(dds, blind=TRUE)
#         saveRDS(transformed, file = "transformed_dds.rds")
#
#     } else {
#
#         transformed_dds <- readRDS(file = "transformed_dds.rds")
# }
# Out:
# R[write to console]: rlog() may take a long time with 50 or more samples,
# vst() is a much faster transformation

# %%
# %%R
#
# # Get the summarized experiement object, which is a matrix of the transformed counts
# # Save this matrix to the temp folder
#
# transformed_dds_matrix <- assay(transformed_dds)
# write.csv(transformed_dds_matrix, "temp/transfored_dds_matrix.csv")

# %%
# Load the transforemed_dds_matrix with pandas

transformed_dds_matrix = pd.read_csv("temp/transfored_dds_matrix.csv")
transformed_dds_matrix = transformed_dds_matrix.rename(index=str, columns={"Unnamed: 0": "Ensembl_ID"})

# %%
# Calculate the 75th percentile of each row

# Need to slice only the columns for samples
sample_columns = transformed_dds_matrix.columns.values[1:]
transformed_dds_matrix['75th_percentile'] = transformed_dds_matrix[sample_columns].apply(lambda x: np.percentile(x, 75), axis=1)

# %%
# calculate the median for each row 

transformed_dds_matrix['median'] = transformed_dds_matrix[sample_columns].apply(lambda x: np.median(x), axis=1)

# %%
# Download "merge_clinical" clinical data from firebrowse http://gdac.broadinstitute.org/runs/stddata__2016_01_28/data/PAAD/20160128/gdac.broadinstitute.org_PAAD.Merge_Clinical.Level_1.2016012800.0.0.tar.gz
# Extract and place the "PAAD.merged_only_clinical_clin_format.txt" file in the "data/clinical" folder
# Read the Clinical file, in this case I transposed it to keep the clinical feature title as column name
clinical_dir = 'data/clinical/PAAD.merged_only_clinical_clin_format.txt'
clinical_df = pd.read_csv(clinical_dir, sep='\t', index_col='V1').T

# %%
# Visualize the head of the file
clinical_df.head()
# Out:
# V1 admin.batch_number                       admin.bcr admin.day_of_dcc_upload  \
# V2           424.43.0  nationwide children's hospital                      21
# V3           424.43.0  nationwide children's hospital                      21
# V4           424.43.0  nationwide children's hospital                      21
# V5           424.43.0  nationwide children's hospital                      21
# V6           424.43.0  nationwide children's hospital                      21
#
# V1 admin.disease_code                       admin.file_uuid  \
# V2               paad  cda0d295-ea13-4065-9e5d-8177e827a8f6
# V3               paad  d25a44b7-47b1-4a1b-ae08-7bd9aceab9c8
# V4               paad  6f72d859-d6af-4a35-8836-2e086684d90f
# V5               paad  ca534fd7-dad2-4bd8-9017-391bb314c4a8
# V6               paad  650295d6-db83-4fa3-909e-4640a77e6274
#
# V1 admin.month_of_dcc_upload admin.patient_withdrawal.withdrawn  \
# V2                         1                              false
# V3                         1                              false
# V4                         1                              false
# V5                         1                              false
# V6                         1                              false
#
# V1 admin.project_code admin.year_of_dcc_upload patient.additional_studies  \
# V2               tcga                     2016                        NaN
# V3               tcga                     2016                        NaN
# V4               tcga                     2016                        NaN
# V5               tcga                     2016                        NaN
# V6               tcga                     2016                        NaN
#
# V1  ... patient.tissue_prospective_collection_indicator  \
# V2  ...                                              no
# V3  ...                                              no
# V4  ...                                              no
# V5  ...                                              no
# V6  ...                                              no
#
# V1 patient.tissue_retrospective_collection_indicator  \
# V2                                               yes
# V3                                               yes
# V4                                               yes
# V5                                               yes
# V6                                               yes
#
# V1 patient.tissue_source_site patient.tobacco_smoking_history  \
# V2                         2j                               3
# V3                         2j                               5
# V4                         2j                             NaN
# V5                         2j                             NaN
# V6                         2j                               1
#
# V1 patient.tumor_tissue_site patient.tumor_type patient.vital_status  \
# V2                  pancreas            primary                 dead
# V3                  pancreas            primary                alive
# V4                  pancreas            primary                 dead
# V5                  pancreas            primary                alive
# V6                  pancreas            primary                 dead
#
# V1 patient.year_of_form_completion  \
# V2                            2014
# V3                            2014
# V4                            2014
# V5                            2014
# V6                            2014
#
# V1 patient.year_of_initial_pathologic_diagnosis  \
# V2                                         2012
# V3                                         2012
# V4                                         2012
# V5                                         2012
# V6                                         2012
#
# V1 patient.year_of_tobacco_smoking_onset
# V2                                  1962
# V3                                   NaN
# V4                                   NaN
# V5                                   NaN
# V6                                   NaN
#
# [5 rows x 440 columns]

# %%
# Convert patient barcodes to uppercase
clinical_df['patient.bcr_patient_barcode'] = clinical_df['patient.bcr_patient_barcode'].str.upper()

# %%
# Days to new tumor event after initial treatment are listed in several columns.
# If there are multiple records for this, we need to take the first value (earliest recorded value)

new_tumor_df = pd.DataFrame()
new_tumor_df['patient.bcr_patient_barcode']  = clinical_df['patient.bcr_patient_barcode']
for column in clinical_df:
    if 'days_to_new_tumor_event_after_initial_treatment' in column:
        new_tumor_df[column] = clinical_df[column]
        new_tumor_df[column] = new_tumor_df[column].astype(float)
        new_tumor_df['new_tumor_days'] = new_tumor_df.min(axis=1)
        
new_tumor_df = new_tumor_df[['patient.bcr_patient_barcode', 'new_tumor_days']]

# %%
# Similarly get the earliest recording of days to death
# This should be unambiguous, but we take the max anyway just to pick one value if there are multiple entries

death_df = pd.DataFrame()
death_df['patient.bcr_patient_barcode']  = clinical_df['patient.bcr_patient_barcode']
for column in clinical_df:
    if 'days_to_death' in column:
        death_df[column] = clinical_df[column]
        death_df[column] = death_df[column].astype(float)
        death_df['death_days'] = death_df.max(axis=1)

death_df = death_df[['patient.bcr_patient_barcode', 'death_days']]

# %%
# Similarly get the most recent number for "days to last followup"
# Days_to_last_followup is the time interval from the date of last followup to the date of initial pathologic diagnosis
# This means the most recent followup would be the largest number

followup_df = pd.DataFrame()
followup_df['patient.bcr_patient_barcode']  = clinical_df['patient.bcr_patient_barcode']
for column in clinical_df:
    if 'days_to_last_followup' in column:
        followup_df[column] = clinical_df[column]
        followup_df[column] = followup_df[column].astype(float)
        followup_df['followup_days'] = followup_df.max(axis=1)

followup_df = followup_df[['patient.bcr_patient_barcode', 'followup_days']]

# %%
# Merge new_tumor_df, death_df, followup_df
df_list = [new_tumor_df, death_df, followup_df]
all_clinical_df = pd.DataFrame()
all_clinical_df['patient.bcr_patient_barcode'] = clinical_df['patient.bcr_patient_barcode']
for df in df_list:
    all_clinical_df = all_clinical_df.merge(df, on='patient.bcr_patient_barcode')

# %%
# Need to create a column for death that takes into account samples that need to be censored (patients that did not die)
# If the patient did die, the time to death will be recorded in this column
# If the patient did not die, the number of days since last followup will be recorded in this column

all_clinical_df['new_death']= np.where(all_clinical_df['death_days'].isnull(),all_clinical_df['followup_days'] , all_clinical_df['death_days'])

# %%
# Need to create a column for time to new tumor that takes into account censored patients
# If the patient has a non-null new_tumor_days value, this value will be recorded in this column
# If the patient did not develop a new tumor, then the days since last followup will be used in this column 
all_clinical_df['new_time'] = np.where(all_clinical_df['new_tumor_days'].isnull(), all_clinical_df['followup_days'], all_clinical_df['new_tumor_days'])

# %%
# Translate the alive and dead strings in the patient.vital_status column to 1 for dead and 0 for alive

alive_dead_df = clinical_df[['patient.bcr_patient_barcode', 'patient.vital_status']]
alive_dead_df['death_event'] = np.where(alive_dead_df['patient.vital_status'] == 'dead', 1, 0)
alive_dead_df = alive_dead_df[['patient.bcr_patient_barcode', 'death_event']]
# Out:
# /home/brett/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# Merge the alive/dead data with the all_clincal_df data

all_clinical_df = all_clinical_df.merge(alive_dead_df, on='patient.bcr_patient_barcode')

# %%
# Function can be used to find a gene from an ensembl root
def find_gene_id(id):
    for item in transformed_dds_matrix['Ensembl_ID']:
        if id in item:
            return item
            
# The root ensembl id for MET is ENSG00000105976

print(find_gene_id('ENSG00000105976'))
# Out:
# ENSG00000105976.13

# %%
# Select row from transformed_dds_matrix with our gene of interest
gene_of_interest = find_gene_id('ENSG00000105976')
transformed_dds_matrix[transformed_dds_matrix['Ensembl_ID'] == gene_of_interest]
# Out:
#               Ensembl_ID  TCGA-2J-AAB1-01A.tsv  TCGA-2J-AAB4-01A.tsv  \
# 3159  ENSG00000105976.13             12.579738             12.391897
#
#       TCGA-2J-AAB6-01A.tsv  TCGA-2J-AAB8-01A.tsv  TCGA-2J-AAB9-01A.tsv  \
# 3159             13.724667              12.40901             12.661981
#
#       TCGA-2J-AABA-01A.tsv  TCGA-2J-AABE-01A.tsv  TCGA-2J-AABF-01A.tsv  \
# 3159             12.556881             12.467062             12.655133
#
#       TCGA-2J-AABH-01A.tsv  ...  TCGA-XD-AAUI-01A.tsv  TCGA-XD-AAUL-01A.tsv  \
# 3159             12.918456  ...             12.686107             12.854646
#
#       TCGA-XN-A8T3-01A.tsv  TCGA-XN-A8T5-01A.tsv  TCGA-YB-A89D-01A.tsv  \
# 3159              11.91496             12.755337             12.567001
#
#       TCGA-YH-A8SY-01A.tsv  TCGA-YY-A8LH-01A.tsv  TCGA-Z5-AAPL-01A.tsv  \
# 3159             12.261489             12.421034             11.478104
#
#       75th_percentile     median
# 3159        12.958448  12.531897
#
# [1 rows x 181 columns]

# %%
# Make a list 
all_clinical_df
# Out:
#     patient.bcr_patient_barcode  new_tumor_days  death_days  followup_days  \
# 0                  TCGA-2J-AAB1             NaN        66.0            NaN
# 1                  TCGA-2J-AAB4             NaN         NaN          729.0
# 2                  TCGA-2J-AAB6           169.0       293.0            NaN
# 3                  TCGA-2J-AAB8             NaN         NaN           80.0
# 4                  TCGA-2J-AAB9           521.0       627.0            NaN
# 5                  TCGA-2J-AABA           160.0       607.0            NaN
# 6                  TCGA-2J-AABE             NaN         NaN          676.0
# 7                  TCGA-2J-AABF           443.0       691.0            NaN
# 8                  TCGA-2J-AABH          1287.0         NaN         1287.0
# 9                  TCGA-2J-AABI           728.0         NaN          969.0
# 10                 TCGA-2J-AABK             NaN         NaN          484.0
# 11                 TCGA-2J-AABO           439.0         NaN          440.0
# 12                 TCGA-2J-AABP             NaN         NaN          463.0
# 13                 TCGA-2J-AABR           327.0         NaN          438.0
# 14                 TCGA-2J-AABT             NaN         NaN          319.0
# 15                 TCGA-2J-AABU           154.0       277.0            NaN
# 16                 TCGA-2J-AABV           126.0       652.0            NaN
# 17                 TCGA-2L-AAQA             NaN       143.0            NaN
# 18                 TCGA-2L-AAQE             NaN       684.0            NaN
# 19                 TCGA-2L-AAQI             NaN       103.0            NaN
# 20                 TCGA-2L-AAQJ             NaN       394.0            NaN
# 21                 TCGA-2L-AAQL             NaN       292.0            NaN
# 22                 TCGA-2L-AAQM             NaN         NaN         1383.0
# 23                 TCGA-3A-A9I5             NaN         NaN         1794.0
# 24                 TCGA-3A-A9I7          1309.0         NaN         1323.0
# 25                 TCGA-3A-A9I9           513.0       634.0            NaN
# 26                 TCGA-3A-A9IB             NaN       224.0            NaN
# 27                 TCGA-3A-A9IC             NaN       738.0            NaN
# 28                 TCGA-3A-A9IH           763.0         NaN         1021.0
# 29                 TCGA-3A-A9IJ             NaN         NaN         1854.0
# ..                          ...             ...         ...            ...
# 155                TCGA-LB-A7SX             NaN       393.0          127.0
# 156                TCGA-LB-A8F3             NaN         NaN          379.0
# 157                TCGA-LB-A9Q5           290.0       313.0          155.0
# 158                TCGA-M8-A5N4           416.0         NaN          584.0
# 159                TCGA-OE-A75W           146.0       267.0          110.0
# 160                TCGA-PZ-A5RE           393.0       470.0          247.0
# 161                TCGA-Q3-A5QY             NaN         NaN          416.0
# 162                TCGA-Q3-AA2A             NaN         NaN           95.0
# 163                TCGA-RB-A7B8           449.0       466.0           36.0
# 164                TCGA-RB-AA9M           258.0         NaN          286.0
# 165                TCGA-RL-AAAS             NaN         NaN            9.0
# 166                TCGA-S4-A8RM             NaN         NaN          737.0
# 167                TCGA-S4-A8RO           291.0         NaN          525.0
# 168                TCGA-S4-A8RP             NaN       702.0            NaN
# 169                TCGA-US-A774           366.0       695.0            NaN
# 170                TCGA-US-A776             NaN         NaN         1216.0
# 171                TCGA-US-A779             NaN       511.0            NaN
# 172                TCGA-US-A77E           166.0       430.0            NaN
# 173                TCGA-US-A77G             NaN        12.0            NaN
# 174                TCGA-US-A77J             NaN       568.0            NaN
# 175                TCGA-XD-AAUG             NaN         NaN          420.0
# 176                TCGA-XD-AAUH            87.0         NaN          395.0
# 177                TCGA-XD-AAUI           175.0       366.0          202.0
# 178                TCGA-XD-AAUL             NaN         NaN          498.0
# 179                TCGA-XN-A8T3           461.0         NaN          951.0
# 180                TCGA-XN-A8T5           242.0         NaN          720.0
# 181                TCGA-YB-A89D             NaN         NaN          350.0
# 182                TCGA-YH-A8SY             NaN         NaN          388.0
# 183                TCGA-YY-A8LH             NaN         NaN         2016.0
# 184                TCGA-Z5-AAPL             NaN         NaN          467.0
#
#      new_death  new_time  death_event
# 0         66.0       NaN            1
# 1        729.0     729.0            0
# 2        293.0     169.0            1
# 3         80.0      80.0            0
# 4        627.0     521.0            1
# 5        607.0     160.0            1
# 6        676.0     676.0            0
# 7        691.0     443.0            1
# 8       1287.0    1287.0            0
# 9        969.0     728.0            0
# 10       484.0     484.0            0
# 11       440.0     439.0            0
# 12       463.0     463.0            0
# 13       438.0     327.0            0
# 14       319.0     319.0            0
# 15       277.0     154.0            1
# 16       652.0     126.0            1
# 17       143.0       NaN            1
# 18       684.0       NaN            1
# 19       103.0       NaN            1
# 20       394.0       NaN            1
# 21       292.0       NaN            1
# 22      1383.0    1383.0            0
# 23      1794.0    1794.0            0
# 24      1323.0    1309.0            0
# 25       634.0     513.0            1
# 26       224.0       NaN            1
# 27       738.0       NaN            1
# 28      1021.0     763.0            0
# 29      1854.0    1854.0            0
# ..         ...       ...          ...
# 155      393.0     127.0            0
# 156      379.0     379.0            0
# 157      313.0     290.0            0
# 158      584.0     416.0            0
# 159      267.0     146.0            0
# 160      470.0     393.0            0
# 161      416.0     416.0            0
# 162       95.0      95.0            0
# 163      466.0     449.0            0
# 164      286.0     258.0            0
# 165        9.0       9.0            0
# 166      737.0     737.0            0
# 167      525.0     291.0            0
# 168      702.0       NaN            1
# 169      695.0     366.0            1
# 170     1216.0    1216.0            0
# 171      511.0       NaN            1
# 172      430.0     166.0            1
# 173       12.0       NaN            1
# 174      568.0       NaN            1
# 175      420.0     420.0            0
# 176      395.0      87.0            0
# 177      366.0     175.0            0
# 178      498.0     498.0            0
# 179      951.0     461.0            0
# 180      720.0     242.0            0
# 181      350.0     350.0            0
# 182      388.0     388.0            0
# 183     2016.0    2016.0            0
# 184      467.0     467.0            0
#
# [185 rows x 7 columns]
